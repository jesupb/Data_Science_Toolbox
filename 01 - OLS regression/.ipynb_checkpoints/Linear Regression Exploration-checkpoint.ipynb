# %%
import os
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')

# %%
# Based on the analysis from https://www.kaggle.com/code/sudhirnl7/linear-regression-tutorial

# %%
# Load data
df = pd.read_csv('insurance.csv')

# %%
# Data exploration
#  Start by understanding the data (categorical vs. numeric, what's the range ie. min() and max())
print(df.head())
print('')
print(df.describe())
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Check for missing values
plt.figure(figsize=(12,4))
sns.heatmap(df.isnull(),cbar=False,cmap='viridis',yticklabels=False)
plt.title('Missing value in the dataset');

# No missing values!

# %%
# Check for correlated variables
corr = df.corr()
sns.heatmap(corr, cmap = 'Wistia', annot= True);

# There doesn't seem to be any correlation between quantitative variables

# %%
# Check for normality of the target variable
f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df['charges'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of insurance charges')

ax=f.add_subplot(122)
sns.distplot(np.log(df['charges']),bins=40,color='b',ax=ax)
ax.set_title('Distribution of insurance charges in $log$ scale')
ax.set_xscale('log');
# Out:
# C:\Users\Jesus Pacheco\miniconda3\envs\6.86x\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Jesus Pacheco\miniconda3\envs\6.86x\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Normality doesn't semm to be that great. 
from scipy import stats
normality_test = stats.shapiro(np.log(df['charges']))

print('Normality test p-value is: ' + str(normality_test[1]))
# Out:
# Normality test p-value is: 2.2936005525386882e-11

# %%
# data is not normal, so we might need to normalize with a Box Cox transformation
from scipy.stats import boxcox
y_bc,lam, ci= boxcox(df['charges'],alpha=0.05)

print(lam, ci)

print(y_bc) 
print(df['charges'])
# Out:
# 0.043649053770664956 (-0.01140290617294196, 0.0988096859767545)
# [12.12897974  8.80859638 10.14752106 ...  8.72968299  9.01913128
#  12.9736611 ]
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64
